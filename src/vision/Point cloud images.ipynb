# %%
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread('/tmp/z_img.png')

# %%
plt.imshow(img, cmap='viridis')

# %%
img = cv2.imread('/tmp/z_img.png', cv2.IMREAD_GRAYSCALE)

plt.imshow(img, cmap='prism')

plt.show()

# %%
import numpy as np

# %%
mask[np.where(img < 0.05)]
# Out:
# (array([352, 352, 352, ..., 479, 479, 479]),
#  array([  0,   1,   2, ..., 637, 638, 639]))

# %%
mask=np.zeros(img.shape)
mask[np.where(img < 0.05)]=1

# %%
plt.imshow(mask)
